# %%
# !pip install dataclasses
# !pip install hydra-core
# !pip install fastBPE regex requests sacremoses subword_nmt
# !pip install clipper_admin
# !docker build -t custom-model-image .

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# udev            7.7G     0  7.7G   0% /dev
# tmpfs           1.6G  792K  1.6G   1% /run
# /dev/nvme0n1p1  194G  101G   94G  52% /
# tmpfs           7.7G   12K  7.7G   1% /dev/shm
# tmpfs           5.0M     0  5.0M   0% /run/lock
# tmpfs           7.7G     0  7.7G   0% /sys/fs/cgroup
# /dev/loop1       98M   98M     0 100% /snap/core/10185
# /dev/loop2       94M   94M     0 100% /snap/core/8935
# /dev/loop3       33M   33M     0 100% /snap/amazon-ssm-agent/2996
# /dev/loop0       29M   29M     0 100% /snap/amazon-ssm-agent/2012
# /dev/loop4       56M   56M     0 100% /snap/core18/1932
# tmpfs           1.6G     0  1.6G   0% /run/user/1000

# %%
#Start clipper
from clipper_admin import ClipperConnection, DockerContainerManager
clipper_conn = ClipperConnection(DockerContainerManager())
clipper_conn.start_clipper()
# Out:
# 20-11-30:22:34:01 INFO     [docker_container_manager.py:184] [default-cluster] Starting managed Redis instance in Docker
# 20-11-30:22:34:03 INFO     [docker_container_manager.py:276] [default-cluster] Metric Configuration Saved at /tmp/tmp9_sga089.yml
# 20-11-30:22:34:03 INFO     [clipper_admin.py:162] [default-cluster] Clipper is running

# %%
# !docker ps
# Out:
# CONTAINER ID        IMAGE                               COMMAND                  CREATED             STATUS                  PORTS                                            NAMES
# c04c3614cc4a        prom/prometheus:v2.9.2              "/bin/prometheus --c…"   1 second ago        Up Less than a second   0.0.0.0:9090->9090/tcp                           metric_frontend-30229
# 07b02e784694        clipper/frontend-exporter:0.4.1     "python /usr/src/app…"   1 second ago        Up Less than a second                                                    query_frontend_exporter-34886
# d1bcf9160443        clipper/query_frontend:0.4.1        "/clipper/query_fron…"   1 second ago        Up Less than a second   0.0.0.0:1337->1337/tcp, 0.0.0.0:7000->7000/tcp   query_frontend-34886
# 5a59edaa3488        clipper/management_frontend:0.4.1   "/clipper/mgmt_front…"   2 seconds ago       Up 1 second             0.0.0.0:1338->1338/tcp                           mgmt_frontend-12863
# 95814de241e1        redis:alpine                        "docker-entrypoint.s…"   3 seconds ago       Up 1 second             0.0.0.0:6379->6379/tcp                           redis-49410

# %%
# !df -h

# %%
clipper_conn.stop_all()

# %%
clipper_conn.get_clipper_logs()
